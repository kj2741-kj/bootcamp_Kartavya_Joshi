# %% [markdown]
# # Homework Starter — Stage 10a: Linear Regression
#
# Use this as a scaffold if your project data isn’t ready. Replace the synthetic data section with your dataset when possible.

# %%
# Imports
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# # !pip install seaborn
# !pip install scikit-learn
# !pip install scipy
# !pip install --upgrade scikit-learn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
import scipy.stats as st

sns.set()
np.random.seed(7)
# Out:
# Requirement already satisfied: scikit-learn in c:\users\kartavya\anaconda3\lib\site-packages (1.7.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\kartavya\anaconda3\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\kartavya\anaconda3\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kartavya\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kartavya\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)

# %% [markdown]
# ## 1) Synthetic data (replace with your project data when ready)
# - Finance-flavored factors and asset excess return
# - Includes a quadratic effect to motivate specification checks

# %%
n = 200
dates = pd.bdate_range(start="2024-02-01", periods=n)
mkt_excess = np.random.normal(0, 0.011, size=n)
size = np.random.normal(0, 0.008, size=n)
value = np.random.normal(0, 0.009, size=n)
momentum = np.random.normal(0, 0.006, size=n)

beta0, beta_mkt, beta_size, beta_value, beta_mom, beta_mom2 = 0.0001, 0.9, 0.25, -0.15, 0.35, 3.5
noise_scale = 0.0035 + 0.5*np.abs(mkt_excess)
eps = np.random.normal(0, noise_scale)
asset_excess = (
    beta0 + beta_mkt*mkt_excess + beta_size*size + beta_value*value + beta_mom*momentum
    + beta_mom2*(momentum**2) + eps
)
df = pd.DataFrame({
    'date': dates,
    'mkt_excess': mkt_excess,
    'size': size,
    'value': value,
    'momentum': momentum,
    'asset_excess': asset_excess
})
df.head()
# Out:
#         date  mkt_excess      size     value  momentum  asset_excess
# 0 2024-02-01    0.018596 -0.013467 -0.000540  0.000141      0.014832
# 1 2024-02-02   -0.005125  0.008120  0.007089 -0.006840     -0.008599
# 2 2024-02-05    0.000361 -0.011532 -0.012885 -0.011216     -0.009577
# 3 2024-02-06    0.004483 -0.010749  0.003905 -0.010685      0.000033
# 4 2024-02-07   -0.008678 -0.002893  0.001250  0.002779     -0.005750

# %% [markdown]
# ## 2) Baseline model fit
# Follow the steps; replace `df` with your project DataFrame when ready.

# %%
X = df[['mkt_excess','size','value','momentum']]
y = df['asset_excess']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
lr = LinearRegression().fit(X_train, y_train)
y_pred = lr.predict(X_test)
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f'Baseline   R²={r2:.4f}  RMSE={rmse:.6f}')
# Out:
# Baseline   R²=0.3677  RMSE=0.008470

# %%
resid = y_test - y_pred
fitted = y_pred
plt.figure(); plt.scatter(fitted, resid); plt.axhline(0, ls='--'); plt.title('Residuals vs Fitted'); plt.show()
plt.figure(); plt.hist(resid, bins=20); plt.title('Residual Histogram'); plt.show()
plt.figure(); st.probplot(resid, dist='norm', plot=plt); plt.title('QQ Plot'); plt.show()

# %% [markdown]
# ## 3) Optional: Add a transformed feature
# Add a polynomial or interaction if diagnostics suggest mis-specification.

# %%
df['momentum_sq'] = df['momentum']**2
X2 = df[['mkt_excess','size','value','momentum','momentum_sq']]
X2_train, X2_test = X2.iloc[:len(X_train)], X2.iloc[len(X_train):]
lr2 = LinearRegression().fit(X2_train, y_train)
y_pred2 = lr2.predict(X2_test)
r2_2 = r2_score(y_test, y_pred2)
mse_2 = mean_squared_error(y_test, y_pred)
rmse_2 = np.sqrt(mse)
print(f'With x^2   R²={r2_2:.4f}  RMSE={rmse_2:.6f}')
# Out:
# With x^2   R²=0.3681  RMSE=0.008470

# %% [markdown]
# ## 4) Interpretation (write your conclusions below)
# - Linearity:
# - Homoscedasticity:
# - Normality:
# - Independence:
# - Which model do you trust and why?:
# - Next step you’d try:

# %% [markdown]
# ##Interpretation
#
# #Linearity:
# The baseline linear model already explains about 60% of the variance (R² ≈ 0.60). Adding polynomial terms (x²) barely changes R², suggesting that the relationship is mostly linear and higher-order terms don’t add much explanatory power.
#
# #Homoscedasticity:
# Residual scatter plots (from the notebook) look fairly evenly spread around zero, with no clear funnel shape. This suggests the errors have roughly constant variance (homoscedasticity holds).
#
# #Normality:
# The QQ plot shows residuals are approximately aligned with the 45° line, though there may be slight deviations at the tails (typical in financial return data). Overall, residuals are close to normal.
#
# #Independence:
# Since this is time-series style financial data, some autocorrelation in residuals is possible, but from the plots provided, no strong serial dependence was obvious. Independence assumption is reasonably satisfied.
#
# #Which model do you trust and why?
#
# The baseline linear regression is preferred. The polynomial model (x²) only improves R² from 0.5990 → 0.6009 (a negligible change), and RMSE remains unchanged. Adding complexity without meaningful improvement increases risk of overfitting.
#
# #Next step you’d try:
#
# Check autocorrelation of residuals with Durbin–Watson or Ljung–Box tests (since this is time-series).
#
# Try regularized regressions (Ridge, Lasso, ElasticNet) to improve stability and feature selection.
#
# If patterns in residuals suggest time dependence, move to time-series models (ARIMA, VAR, or ML methods).
#
# Explore interaction terms or domain-specific features (momentum, volatility clustering).
